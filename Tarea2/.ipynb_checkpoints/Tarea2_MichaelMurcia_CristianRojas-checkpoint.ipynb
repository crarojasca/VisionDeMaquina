# %%
from matplotlib import pyplot as plt
from IPython.display import Image
import numpy as np
import pywt
import cv2
import math

img = cv2.imread("Figures/Lenna.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(1)
plt.imshow(img)
plt.show()

# %%
def w2d(img, mode='haar', level=1):    
    coeffs=pywt.wavedec2(img, mode, level=level)
    return coeffs[0]

dwtImg = w2d(img)

plt.figure(1)
plt.imshow(dwtImg)
plt.show()

# %%
def JPEG(img):
    
    qMtx = np.matrix('16 11 10 16 24 40 51 61;\
                      12 12 14 19 26 58 60 55;\
                      14 13 16 24 40 57 69 56;\
                      14 17 22 29 51 87 80 62;\
                      18 22 37 56 68 109 103 77;\
                      24 35 55 64 81 104 103 92;\
                      49 64 78 77 103 121 120 101;\
                      72 92 95 98 112 100 103 99').astype('float')   
    n = len(qMtx)    
    h = img.shape[0]
    w = img.shape[1]
    
    cmpImage = np.zeros((h, w), np.uint8)  
    for i in range(0, math.floor(h/n)):
        for j in range(0, math.floor(w/n)):
            sample = img[i*n:i*n+8,j*n:j*n+8]
            imf = np.float32(sample)/255.0
            dct = cv2.dct(imf)
            idct = cv2.idct(dct) 
            cmpImage[i*n:i*n+8,j*n:j*n+8] = (idct*255).astype(int)
    return cmpImage

cmp = JPEG(img)
plt.figure(1)
plt.imshow(cmp)
plt.show()

plt.figure(2)
plt.imshow(img)
plt.show()


#sample = img[0:8,0:8]
#print(sample)

#imf = np.float32(sample)/255.0  # float conversion/scale
#print(imf)

#dct = cv2.dct(imf)           # the dct
#print(dst)

#print((dct/qMtx).astype(int))



#sample = cv2.idct(dst)    # convert back
#print((sample*255).astype(int))

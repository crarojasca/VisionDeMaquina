# %%
from matplotlib import pyplot as plt
from IPython.display import Image
import numpy as np
import cv2
import math
import time

img = cv2.imread("Figures/Lenna.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

speckle = cv2.imread("Figures/Speckle.png")
speckle = cv2.cvtColor(speckle, cv2.COLOR_BGR2GRAY)

plt.figure(1)
plt.subplots_adjust(left=0.0, right=1.5, bottom=0.0, top=1.5)
plt.subplot(121) ,plt.imshow(img, cmap='gray')
plt.title('Lenna')
plt.subplot(122) ,plt.imshow(speckle, cmap='gray')
plt.title('Speckle Noise')
plt.show()

# %%
from scipy.ndimage.filters import uniform_filter
from scipy.ndimage.measurements import variance

def lee_filter(img, n):
    
    h = img.shape[0]
    w = img.shape[1]
    
    img_output = np.zeros((h, w), np.uint8)
    for x in range(0, h, n):
        for y in range(0, w, n):
            block = img[x:x+n,y:y+n]
            block_mean = uniform_filter(block, (n, n))
            block_sqr_mean = uniform_filter(block**2, (n, n))
            block_variance = block_sqr_mean - block_mean**2

            overall_variance = variance(img)

            block_weights = block_variance**2 / (block_variance**2 + overall_variance**2)
            block_output = block_mean + block_weights * (block - block_mean)
            
            img_output[x:x+n,y:y+n] = block_output
    return img_output




   

fltImg = lee_filter(speckle, 6)

plt.figure(1)
plt.subplots_adjust(left=0.0, right=1.5, bottom=0.0, top=1.5)
plt.subplot(121) ,plt.imshow(speckle, cmap='gray')
plt.title('Ruido Speckle')
plt.subplot(122) ,plt.imshow(fltImg, cmap='gray')
plt.title('Filtro Lee')
plt.show()

# %%
def kuan_filter(img, n, L):
    
    h = img.shape[0]
    w = img.shape[1]
    
    img_output = np.zeros((h, w), np.uint8)
    for x in range(0, h, n):
        for y in range(0, w, n):
            block = img[x:x+n,y:y+n]
            block_median = np.median(block)
            block_variance = block.var()
            noise_variance = (L*block_variance - block_median**2)/(L+1)
            block_output = block_median + (noise_variance*(block-block_median))/(noise_variance+(block_variance+noise_variance)/L)
            img_output[x:x+n,y:y+n] = block_output
    return img_output
  

fltImg = kuan_filter(speckle, 4, 0.2)

plt.figure(1)
plt.subplots_adjust(left=0.0, right=1.5, bottom=0.0, top=1.5)
plt.subplot(121) ,plt.imshow(speckle, cmap='gray')
plt.title('Ruido Speckle')
plt.subplot(122) ,plt.imshow(fltImg, cmap='gray')
plt.title('Filtro Kuan')
plt.show()

# %%
def gamma_filter(img, n, L):
    
    h = img.shape[0]
    w = img.shape[1]
    
    img_output = np.zeros((h, w), np.uint8)
    for x in range(0, h, n):
        for y in range(0, w, n):
            block = img[x:x+n,y:y+n]
            block_median = np.median(block)
            block_variance = block.var()
            gamma = (L+1)/(L*(block_variance/block_median)**2 - 1)
            block_output = ((gamma-L-1)*block_median+np.sqrt(block_median**2*(gamma-L-1)**2+4*gamma*L*block*block_median))/(2*gamma) 
            img_output[x:x+n,y:y+n] = block_output
    return img_output
  

fltImg = gamma_filter(speckle, 3, 0.1)

plt.figure(1)
plt.subplots_adjust(left=0.0, right=1.5, bottom=0.0, top=1.5)
plt.subplot(121) ,plt.imshow(speckle, cmap='gray')
plt.title('Ruido Speckle')
plt.subplot(122) ,plt.imshow(fltImg, cmap='gray')
plt.title('Filtro Gamma')
plt.show()

# %%
def oddy_filter(img, n, alfa):
    h = img.shape[0]
    w = img.shape[1]
    
    img_output = np.zeros((h, w), np.uint8)
    for x in range(0, h, n):
        for y in range(0, w, n):            
            block = img[x:x+n,y:y+n]
            block_median = np.median(block)
            m = (1/8)*np.sum(block-block_median)
            if m < alfa*block_median:                
                img_output[x:x+n,y:y+n] = block_median
            else:
                W = np.zeros((n, n), np.uint8)
                for i in range(0,n-1):
                    for j in range(0,n-1):
                        if block[i,j]<=m:
                            W[i,j]=1
                        else:
                            W[i,j]=0
                img_output[x:x+n,y:y+n] = np.sum(W*y)/np.sum(W)
    return img_output
  
fltImg = oddy_filter(speckle, 3, 0.2)

plt.figure(1)
plt.subplots_adjust(left=0.0, right=1.5, bottom=0.0, top=1.5)
plt.subplot(121) ,plt.imshow(speckle, cmap='gray')
plt.title('Ruido Speckle')
plt.subplot(122) ,plt.imshow(fltImg, cmap='gray')
plt.title('Filtro Oddy')
plt.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in ulong_scalars

# %%
def SNR(img):
    return np.median(img)/img.var()

print(SNR(fltImg))
# Out:
# 0.054781895242744946

# %%
def ENL(img, window):
    return np.median(img[window[0]:window[1]])/img[window[2]:window[3]].var()

print(ENL(img,[420,430,345,350]))
# Out:
# 0.04987733936480388

# %%
def SSI(img, flt):
    return math.sqrt(flt.var())/np.median(flt) * np.median(img)/math.sqrt(img.var())

print(SSI(speckle,fltImg))
# Out:
# 0.9627012943880306

# %%
def SMPI(img, flt):
    return (1 + abs(np.median(img)-np.median(flt)))*(math.sqrt(flt.var())/math.sqrt(img.var()))

print(SMPI(speckle,fltImg))
# Out:
# 2.934686203860287

# %%
def Qfactor(img, flt, enl):
    ys = np.median(img) - abs(np.median(img) - np.median(flt))
    return ys**2/(enl*flt.var()**2)

print(Qfactor(speckle,fltImg,ENL(img,[420,430,345,350])))
# Out:
# 0.05155279654981679
